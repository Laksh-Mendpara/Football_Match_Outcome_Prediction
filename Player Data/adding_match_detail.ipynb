# %%
# Primary libraries
from time import time
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# Measures
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score, accuracy_score, recall_score, confusion_matrix, precision_score, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("./dataset/final_data.csv", index_col=0)
df.tail()
# Out:
#        match_api_id  home_team_buildUpPlaySpeed  home_team_buildUpPlayPassing  \
# 13209     2030167.0                        57.0                          50.0
# 13210     2030168.0                        42.0                          36.0
# 13211     2030169.0                        46.0                          39.0
# 13212     2030170.0                        57.0                          59.0
# 13213     2030171.0                        29.0                          44.0
#
#        home_team_chanceCreationPassing  home_team_chanceCreationCrossing  \
# 13209                             61.0                              62.0
# 13210                             41.0                              40.0
# 13211                             50.0                              60.0
# 13212                             61.0                              63.0
# 13213                             44.0                              44.0
#
#        home_team_chanceCreationShooting  home_team_defencePressure  \
# 13209                              49.0                       49.0
# 13210                              50.0                       47.0
# 13211                              36.0                       49.0
# 13212                              51.0                       48.0
# 13213                              47.0                       54.0
#
#        home_team_defenceAggression  home_team_defenceTeamWidth  \
# 13209                         42.0                        52.0
# 13210                         37.0                        52.0
# 13211                         57.0                        50.0
# 13212                         45.0                        62.0
# 13213                         52.0                        63.0
#
#        home_team_avg_shots  ...  away_player_3_overall_rating  \
# 13209            11.158163  ...                          82.0
# 13210             9.678322  ...                          75.0
# 13211            10.117647  ...                          74.0
# 13212             9.684211  ...                          72.0
# 13213            11.293478  ...                          75.0
#
#        away_player_4_overall_rating  away_player_5_overall_rating  \
# 13209                          80.0                          80.0
# 13210                          77.0                          75.0
# 13211                          76.0                          73.0
# 13212                          76.0                          71.0
# 13213                          76.0                          71.0
#
#        away_player_6_overall_rating  away_player_7_overall_rating  \
# 13209                          82.0                          79.0
# 13210                          75.0                          77.0
# 13211                          71.0                          75.0
# 13212                          79.0                          75.0
# 13213                          76.0                          77.0
#
#        away_player_8_overall_rating  away_player_9_overall_rating  \
# 13209                          77.0                          80.0
# 13210                          76.0                          74.0
# 13211                          73.0                          76.0
# 13212                          71.0                          75.0
# 13213                          74.0                          75.0
#
#        away_player_10_overall_rating  away_player_11_overall_rating  outcome
# 13209                           79.0                           75.0      Win
# 13210                           73.0                           78.0      Win
# 13211                           77.0                           72.0      Win
# 13212                           72.0                           79.0     Draw
# 13213                           73.0                           78.0      Win
#
# [5 rows x 62 columns]

# %%
matches = pd.read_csv("./dataset/matches.csv", index_col=0)
matches = matches.drop(['id'], axis = 1)
matches = matches[['country_id', 'league_id', 'season', 'stage', 'date', 'match_api_id', 'home_team_api_id', 'away_team_api_id']]
matches.tail()
# Out:
#        country_id  league_id     season  stage                 date  \
# 25974       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id
# 25974       1992091             10190             10191
# 25975       1992092              9824             10199
# 25976       1992093              9956             10179
# 25977       1992094              7896             10243
# 25978       1992095             10192              9931

# %%
with sqlite3.connect("dataset/database.sqlite") as con:
    team = pd.read_sql_query("SELECT distinct * from team",con)

team.tail()
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG

# %%
team = team.drop(['id'], axis=1)

# %%
matches = pd.merge(matches, team, left_on='home_team_api_id', right_on='team_api_id')
matches = matches.drop(['team_api_id', 'team_fifa_api_id'], axis=1).rename(columns = {'team_long_name': 'home_team_long_name', 'team_short_name': 'home_team_short_name'})
matches.tail()
# Out:
#        country_id  league_id     season  stage                 date  \
# 25974       24558      24558  2015/2016     34  2016-05-16 00:00:00
# 25975       24558      24558  2015/2016     36  2016-05-25 00:00:00
# 25976       24558      24558  2015/2016      6  2015-08-22 00:00:00
# 25977       24558      24558  2015/2016      7  2015-08-29 00:00:00
# 25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id home_team_long_name  \
# 25974       1992217              7896             10192              Lugano
# 25975       1992226              7896             10190              Lugano
# 25976       1992076              7896              9931              Lugano
# 25977       1992081              7896             10199              Lugano
# 25978       1992094              7896             10243              Lugano
#
#       home_team_short_name
# 25974                  LUG
# 25975                  LUG
# 25976                  LUG
# 25977                  LUG
# 25978                  LUG

# %%
matches = pd.merge(matches, team, left_on='away_team_api_id', right_on='team_api_id')
matches = matches.drop(['team_api_id', 'team_fifa_api_id'], axis=1).rename(columns = {'team_long_name': 'away_team_long_name', 'team_short_name': 'away_team_short_name'})
matches.tail()
# Out:
#        country_id  league_id     season  stage                 date  \
# 25974       24558      24558  2012/2013      8  2012-09-01 00:00:00
# 25975       24558      24558  2013/2014     29  2014-04-12 00:00:00
# 25976       24558      24558  2013/2014      4  2013-08-03 00:00:00
# 25977       24558      24558  2015/2016     18  2015-12-06 00:00:00
# 25978       24558      24558  2015/2016     32  2016-05-08 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id home_team_long_name  \
# 25974       1227772              7730              9956  FC Lausanne-Sports
# 25975       1471923              7730              9956  FC Lausanne-Sports
# 25976       1471649              7730              9956  FC Lausanne-Sports
# 25977       1992136              7896              9956              Lugano
# 25978       1992206              7896              9956              Lugano
#
#       home_team_short_name      away_team_long_name away_team_short_name
# 25974                  LAU  Grasshopper Club Zürich                  GRA
# 25975                  LAU  Grasshopper Club Zürich                  GRA
# 25976                  LAU  Grasshopper Club Zürich                  GRA
# 25977                  LUG  Grasshopper Club Zürich                  GRA
# 25978                  LUG  Grasshopper Club Zürich                  GRA

# %%
df = pd.merge(df, matches, left_on='match_api_id', right_on='match_api_id')
df.tail()
# Out:
#        match_api_id  home_team_buildUpPlaySpeed  home_team_buildUpPlayPassing  \
# 13209     2030167.0                        57.0                          50.0
# 13210     2030168.0                        42.0                          36.0
# 13211     2030169.0                        46.0                          39.0
# 13212     2030170.0                        57.0                          59.0
# 13213     2030171.0                        29.0                          44.0
#
#        home_team_chanceCreationPassing  home_team_chanceCreationCrossing  \
# 13209                             61.0                              62.0
# 13210                             41.0                              40.0
# 13211                             50.0                              60.0
# 13212                             61.0                              63.0
# 13213                             44.0                              44.0
#
#        home_team_chanceCreationShooting  home_team_defencePressure  \
# 13209                              49.0                       49.0
# 13210                              50.0                       47.0
# 13211                              36.0                       49.0
# 13212                              51.0                       48.0
# 13213                              47.0                       54.0
#
#        home_team_defenceAggression  home_team_defenceTeamWidth  \
# 13209                         42.0                        52.0
# 13210                         37.0                        52.0
# 13211                         57.0                        50.0
# 13212                         45.0                        62.0
# 13213                         52.0                        63.0
#
#        home_team_avg_shots  ...  league_id     season  stage  \
# 13209            11.158163  ...      21518  2015/2016      9
# 13210             9.678322  ...      21518  2015/2016      9
# 13211            10.117647  ...      21518  2015/2016      9
# 13212             9.684211  ...      21518  2015/2016      9
# 13213            11.293478  ...      21518  2015/2016      9
#
#                       date  home_team_api_id  away_team_api_id  \
# 13209  2015-10-25 00:00:00              9906             10267
# 13210  2015-10-24 00:00:00              9864              9783
# 13211  2015-10-26 00:00:00              8315              9869
# 13212  2015-10-24 00:00:00              7878              8603
# 13213  2015-10-23 00:00:00              8370              8558
#
#            home_team_long_name  home_team_short_name  \
# 13209          Atlético Madrid                   AMA
# 13210                Málaga CF                   MAL
# 13211  Athletic Club de Bilbao                   BIL
# 13212               Granada CF                   GRA
# 13213           Rayo Vallecano                   RAY
#
#              away_team_long_name  away_team_short_name
# 13209                Valencia CF                   VAL
# 13210  RC Deportivo de La Coruña                   COR
# 13211     Real Sporting de Gijón                   SPG
# 13212        Real Betis Balompié                   BET
# 13213               RCD Espanyol                   ESP
#
# [5 rows x 73 columns]

# %%
df.to_csv("./dataset/temp_data.csv", index = None)
